# %%
import os
os.getcwd()
os.chdir('/Users/yeganeh/Codes/MovieEEG-SourcePipeline/')

# %%
from src.MovieEEGSourcePipeline.preprocessing import mark_bads, run_ica, load_eeg, set_montage, crop_offset, epoch_and_reject
from src.MovieEEGSourcePipeline.source import _load_epochs
